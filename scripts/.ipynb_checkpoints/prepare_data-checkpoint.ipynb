# %%
import pandas as pd
import json

# %%
df = pd.read_csv('investigations.csv')

# %%
df.head()
# Out:
#     buildId                clientDate  \
# 0  84040967  Aug 19, 2020, 5:26:22 PM
# 1  31498348  Jun 28, 2018, 3:19:47 AM
# 2  47267549  May 23, 2019, 5:34:07 AM
# 3  47267549  May 23, 2019, 5:34:07 AM
# 4  47267569  May 23, 2019, 5:02:51 AM
#
#                                           committers  changeCount  comment  \
# 0  [{'name': 'Emma Starukhina', 'extendedName': '...          698      NaN
# 1                                                 []            0      NaN
# 2  [{'name': 'Julia Alexandrova', 'extendedName':...           20      NaN
# 3  [{'name': 'Julia Alexandrova', 'extendedName':...           20      NaN
# 4  [{'name': 'Julia Alexandrova', 'extendedName':...         5112      NaN
#
#                                          triggeredBy  description  \
# 0  Finish Build Trigger; IntelliJ Platform Produc...          NaN
# 1                                   Schedule Trigger          NaN
# 2  Snapshot dependency; Schedule Trigger; TeamCit...          NaN
# ...

# %%
useless = ['isFixed', 'description', 'comment', 'branchName', 'className']

# %%
df = df.drop(useless, axis=1)

# %%
df.head()
# Out:
#     buildId                clientDate  \
# 0  84040967  Aug 19, 2020, 5:26:22 PM
# 1  31498348  Jun 28, 2018, 3:19:47 AM
# 2  47267549  May 23, 2019, 5:34:07 AM
# 3  47267549  May 23, 2019, 5:34:07 AM
# 4  47267569  May 23, 2019, 5:02:51 AM
#
#                                           committers  changeCount  \
# 0  [{'name': 'Emma Starukhina', 'extendedName': '...          698
# 1                                                 []            0
# 2  [{'name': 'Julia Alexandrova', 'extendedName':...           20
# 3  [{'name': 'Julia Alexandrova', 'extendedName':...           20
# 4  [{'name': 'Julia Alexandrova', 'extendedName':...         5112
#
#                                          triggeredBy  isDefaultBranch  \
# 0  Finish Build Trigger; IntelliJ Platform Produc...             True
# 1                                   Schedule Trigger            False
# 2  Snapshot dependency; Schedule Trigger; TeamCit...             True
# ...

# %%
len((df['testNameId']))
# Out:
# 744

# %%
df['target'] = df['previousResponsible'].apply(lambda str_list: json.loads(str_list.replace('\'', '"'))[0])

# %%
df.head()
# Out:
#     buildId                clientDate  \
# 0  84040967  Aug 19, 2020, 5:26:22 PM
# 1  31498348  Jun 28, 2018, 3:19:47 AM
# 2  47267549  May 23, 2019, 5:34:07 AM
# 3  47267549  May 23, 2019, 5:34:07 AM
# 4  47267569  May 23, 2019, 5:02:51 AM
#
#                                           committers  changeCount  \
# 0  [{'name': 'Emma Starukhina', 'extendedName': '...          698
# 1                                                 []            0
# 2  [{'name': 'Julia Alexandrova', 'extendedName':...           20
# 3  [{'name': 'Julia Alexandrova', 'extendedName':...           20
# 4  [{'name': 'Julia Alexandrova', 'extendedName':...         5112
#
#                                          triggeredBy  isDefaultBranch  \
# 0  Finish Build Trigger; IntelliJ Platform Produc...             True
# 1                                   Schedule Trigger            False
# 2  Snapshot dependency; Schedule Trigger; TeamCit...             True
# ...

# %%
set(df['target'])
# Out:
# {'Aleksey Dobrynin (aleksey.dobrynin)',
#  'Andrey Titov (andrey.titov)',
#  'Evgeny Doroshenko (evgeny.doroshenko)',
#  'Filipp Riabchun (filipp.riabchun)',
#  'Ilya Fomenko (ilya.fomenko)',
#  'Julia Reshetnikova (julia.reshetnikova)',
#  'Pavel Sher (pavel.sher)',
#  'Sergey Pak (sergey.pak)',
#  'Yegor Yarko (yaegor)'}

# %%
df['target'].value_counts()
# Out:
# Ilya Fomenko (ilya.fomenko)                556
# Pavel Sher (pavel.sher)                     92
# Filipp Riabchun (filipp.riabchun)           26
# Julia Reshetnikova (julia.reshetnikova)     24
# Andrey Titov (andrey.titov)                 18
# Sergey Pak (sergey.pak)                     10
# Evgeny Doroshenko (evgeny.doroshenko)        8
# Yegor Yarko (yaegor)                         8
# Aleksey Dobrynin (aleksey.dobrynin)          2
# Name: target, dtype: int64

# %%
df['previousResponsible2'] = df['previousResponsible'].apply(lambda str_list: json.loads(str_list.replace('\'', '"'))[1:])

# %%
df.head(n=100)
# Out:
#      buildId                clientDate  \
# 0   84040967  Aug 19, 2020, 5:26:22 PM
# 1   31498348  Jun 28, 2018, 3:19:47 AM
# 2   47267549  May 23, 2019, 5:34:07 AM
# 3   47267549  May 23, 2019, 5:34:07 AM
# 4   47267569  May 23, 2019, 5:02:51 AM
# ..       ...                       ...
# 95  82158900   Aug 3, 2020, 7:12:34 PM
# 96  82158900   Aug 3, 2020, 7:12:34 PM
# 97  82037296   Aug 2, 2020, 5:02:23 AM
# 98  82037296   Aug 2, 2020, 5:02:23 AM
# 99  82158902   Aug 3, 2020, 7:23:55 PM
#
#                                            committers  changeCount  \
# 0   [{'name': 'Emma Starukhina', 'extendedName': '...          698
# 1                                                  []            0
# 2   [{'name': 'Julia Alexandrova', 'extendedName':...           20
# 3   [{'name': 'Julia Alexandrova', 'extendedName':...           20
# 4   [{'name': 'Julia Alexandrova', 'extendedName':...         5112
# ..                                                ...          ...
# ...

# %%
len(df['previousResponsible2'][i]) for i in range(744))
# Out:
#   File "<ipython-input-49-404d9dbd7cdf>", line 1
#     len(df['previousResponsible2'][i]) for i in range(744))
#                                        ^
# SyntaxError: invalid syntax

# %%
set(df['testSuite'])
# Out:
# {'Agent tests: ',
#  'DB Suite: ',
#  'IDEA runner suite: ',
#  'Ldap Suite: ',
#  'Overview/Agents: ',
#  'Overview/Overview: ',
#  'Server tests: ',
#  'Smoke Tests: Auto-Update Test Scenario: ',
#  'Smoke Tests: Build Verification Tests: ',
#  'System Tests: Smoke Tests: ',
#  'TFS Java SDK Test Suite: ',
#  'Visual Studio Test: ',
#  '[TeamCity] External Make Tests: ',
#  'nuget: nuget integration test: ',
#  'storyshots.test.js: Storyshots: /Error alerts: '}

# %%
df['testNameId'].value_counts()
# Out:
#  1791259342594199780    38
#  6677838524259399197    38
# -3639371091024077385    36
#  6159860086802219024    36
#  7850935268128904239    36
#  5815873171975405504    36
#  5388556271807252230    36
# -3259026975647507807    36
#  3339766714334733208    36
# -621559526513354339     36
# -1665204198366830965    36
#  183045401477554608     36
#  2103613887120467622    36
# -5540656993770176231    30
#  7073029182229342984    24
# -7975875114491193572    20
#  2093301233110334890    14
#  7689804100030756799    12
# -6952445292775164088    10
#  7947374575254019522    10
# -1828660432187194524    10
#  5660251422648497649     8
#  4603130212651668068     8
# -3445566310823311944     8
#  9038676351990403638     8
# -5770084195286479548     6
# -7167385372871972884     6
# -8929370305362479013     6
#  380483693315014820      6
# -7765370657989250226     6
#  4779966926913959842     6
# -4232748521727641301     6
#  6659040006025667743     6
#  6957190986177005317     6
# ...

# %%
json.loads(df['committers'][0].replace('\'', '"'))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-67-2e7731663caf> in <module>
# ----> 1 json.loads(df['committers'][0].replace('\'', '"'))
#
# ~/opt/anaconda3/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~/opt/anaconda3/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ...

# %%
json.loads(df['committers'][0].replace("'", '"').replace('False', '"False"').replace('True', '"True"'))
# Out:
# [{'name': 'Emma Starukhina',
#   'extendedName': 'Emma Starukhina (emma.starukhina)',
#   'email': 'emma.starukhina@jetbrains.com',
#   'id': 1601,
#   'groups': ['BuildServer Installation Managers',
#    'TeamCity Administrators',
#    'TeamCity Developers',
#    'DevOps Team',
#    'JetBrains Internal',
#    'All users',
#    'Unauthorized Users'],
#   'vcsProperties': ['anyVcs'],
#   'isGuest': 'False',
#   'lastLogin': 'Aug 25, 2020, 12:21:28 PM'},
#  {'name': 'Kirill Maximov',
#   'extendedName': 'Kirill Maximov (maxkir)',
#   'email': 'kirill.maximov@jetbrains.com',
#   'id': 3,
#   'groups': ['TeamCity Administrators',
#    'TeamCity Developers',
#    'DevOps Team',
#    'JetBrains Internal',
#    'All users',
#    'Unauthorized Users'],
#   'vcsProperties': ['anyVcs'],
#   'isGuest': 'False',
#   'lastLogin': 'Aug 25, 2020, 3:16:51 PM'},
#  {'name': 'Pavel Sher',
#   'extendedName': 'Pavel Sher (pavel.sher)',
#   'email': 'pavel.sher@jetbrains.com',
#   'id': 4,
# ...

# %%
df['committers2'] = df['committers'].apply(lambda row: json.loads(row.replace("'", '"').replace('False', '"False"').replace('True', '"True"')))

# %%
df['committers2'][0][0]['name']
# Out:
# 'Emma Starukhina'

# %%
df['committers_count'] = df['committers2'].apply(lambda row: len(row))

# %%
df[df['committers'] == '[]']
# Out:
#       buildId                 clientDate committers  changeCount  \
# 1    31498348   Jun 28, 2018, 3:19:47 AM         []            0
# 15   54047772   Sep 20, 2019, 8:57:46 PM         []            0
# 16   54047773   Sep 20, 2019, 9:01:32 PM         []            0
# 30   51650733   Aug 13, 2019, 4:32:13 AM         []            0
# 40   77946471   Jun 30, 2020, 9:17:41 AM         []            0
# ..        ...                        ...        ...          ...
# 724  54209955   Sep 24, 2019, 4:38:19 AM         []            0
# 732  84682988  Aug 25, 2020, 10:44:26 AM         []            0
# 736  68051629   Mar 24, 2020, 4:51:00 AM         []            0
# 737  54047772   Sep 20, 2019, 8:57:46 PM         []            0
# 742  78320477    Jul 3, 2020, 6:01:28 AM         []            0
#
#                                            triggeredBy  isDefaultBranch  \
# 1                                     Schedule Trigger            False
# ...

# %%
df['committers_count'].value_counts()
# Out:
# 22    142
# 0     117
# 24     82
# 21     80
# 20     74
# 27     70
# 1      57
# 26     26
# 29     16
# 23     14
# 2      14
# 25     12
# 3      10
# 4       8
# 9       6
# 36      4
# 18      4
# 13      4
# 39      4
# Name: committers_count, dtype: int64

# %%
df['committers_count'].hist(bins=20)

# %%
to_hist = df['committers_count']

# %%
# for spine in plt.gca().spines.values():
#     spine.set_visible(False)

plt.figure(figsize=[10,8])
n, bins, patches = plt.hist(x=to_hist, bins=25, color='#5b2084',alpha=0.7, rwidth=0.85)
# plt.grid(axis='y', alpha=0.75)
plt.xlabel('Commiters count',fontsize=22)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
# plt.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='on')

plt.gca().spines['right'].set_color('none')
plt.gca().spines['top'].set_color('none')

plt.tick_params(
    right=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False)


plt.show()

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams['font.family']
# Out:
# ['sans-serif']
